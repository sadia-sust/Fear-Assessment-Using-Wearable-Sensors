# %%
import flirt.reader.empatica
import matplotlib.pyplot as plot

eda = flirt.reader.empatica.read_eda_file_into_df("/content/sample_data/P1.csv")
eda_features = flirt.get_eda_features(eda['eda'], 180, 1)

eda_features[['phasic_std']].plot()
plot.title("Participant1")
# Out:
# EDA features:   0%|          | 0/360 [00:00<?, ?it/s]
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: UserWarning: phasic_entropy contains more than 5% (actual: 70.83%) nan, inf, or -inf values. We recommend to delete this feature column.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Text(0.5, 1.0, 'Participant1')

# %%
import flirt.reader.empatica
import matplotlib.pyplot as plot

eda = flirt.reader.empatica.read_eda_file_into_df("/content/sample_data/P2_EDA.csv")
eda_features = flirt.get_eda_features(eda['eda'], 180, 1)

eda_features[['phasic_std']].plot()
plot.title("Participant2")
# Out:
# EDA features:   0%|          | 0/204 [00:00<?, ?it/s]
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: UserWarning: tonic_entropy contains more than 5% (actual: 64.71%) nan, inf, or -inf values. We recommend to delete this feature column.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: UserWarning: phasic_entropy contains more than 5% (actual: 62.25%) nan, inf, or -inf values. We recommend to delete this feature column.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Text(0.5, 1.0, 'Participant2')

# %%
import flirt.reader.empatica
import matplotlib.pyplot as plot

eda = flirt.reader.empatica.read_eda_file_into_df("/content/sample_data/P3_EDA.csv")
eda_features = flirt.get_eda_features(eda['eda'], 180, 1)

eda_features[['phasic_std']].plot()
plot.title("Participant3")
# Out:
# EDA features:   0%|          | 0/192 [00:00<?, ?it/s]
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: UserWarning: phasic_entropy contains more than 5% (actual: 70.31%) nan, inf, or -inf values. We recommend to delete this feature column.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Text(0.5, 1.0, 'Participant3')

# %%
import flirt.reader.empatica
import matplotlib.pyplot as plot

eda = flirt.reader.empatica.read_eda_file_into_df("/content/sample_data/P4_EDA.csv")
eda_features = flirt.get_eda_features(eda['eda'], 180, 1)

eda_features[['phasic_std']].plot()
plot.title("Participant4")
# Out:
# EDA features:   0%|          | 0/167 [00:00<?, ?it/s]
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: UserWarning: tonic_entropy contains more than 5% (actual: 99.4%) nan, inf, or -inf values. We recommend to delete this feature column.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: UserWarning: phasic_entropy contains more than 5% (actual: 77.84%) nan, inf, or -inf values. We recommend to delete this feature column.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Text(0.5, 1.0, 'Participant4')

# %%
import flirt.reader.empatica
import matplotlib.pyplot as plot

eda = flirt.reader.empatica.read_eda_file_into_df("/content/sample_data/P5_EDA.csv")
eda_features = flirt.get_eda_features(eda['eda'], 180, 1)

eda_features[['phasic_std']].plot()
plot.title("Participant5")
# Out:
# EDA features:   0%|          | 0/170 [00:00<?, ?it/s]
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: UserWarning: tonic_entropy contains more than 5% (actual: 14.71%) nan, inf, or -inf values. We recommend to delete this feature column.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: UserWarning: phasic_entropy contains more than 5% (actual: 50.0%) nan, inf, or -inf values. We recommend to delete this feature column.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Text(0.5, 1.0, 'Participant5')

# %%
import flirt.reader.empatica
import matplotlib.pyplot as plot

eda = flirt.reader.empatica.read_eda_file_into_df("/content/sample_data/P6_EDA.csv")
eda_features = flirt.get_eda_features(eda['eda'], 180, 1)

eda_features[['phasic_std']].plot()
plot.title("Participant6")
# Out:
# EDA features:   0%|          | 0/314 [00:00<?, ?it/s]
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: UserWarning: phasic_entropy contains more than 5% (actual: 77.07%) nan, inf, or -inf values. We recommend to delete this feature column.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Text(0.5, 1.0, 'Participant6')

# %%
import flirt.reader.empatica
import matplotlib.pyplot as plot

eda = flirt.reader.empatica.read_eda_file_into_df("/content/sample_data/P7_EDA.csv")
eda_features = flirt.get_eda_features(eda['eda'], 180, 1)

eda_features[['phasic_std']].plot()
plot.title("Participant7")
# Out:
# EDA features:   0%|          | 0/281 [00:00<?, ?it/s]
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: UserWarning: tonic_entropy contains more than 5% (actual: 97.15%) nan, inf, or -inf values. We recommend to delete this feature column.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: UserWarning: phasic_entropy contains more than 5% (actual: 59.79%) nan, inf, or -inf values. We recommend to delete this feature column.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Text(0.5, 1.0, 'Participant7')

# %%
import flirt.reader.empatica
import matplotlib.pyplot as plot

eda = flirt.reader.empatica.read_eda_file_into_df("/content/sample_data/P8_EDA.csv")
eda_features = flirt.get_eda_features(eda['eda'], 180, 1)

eda_features[['phasic_std']].plot()
plot.title("Participant8")
# Out:
# EDA features:   0%|          | 0/158 [00:00<?, ?it/s]
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: UserWarning: tonic_entropy contains more than 5% (actual: 78.48%) nan, inf, or -inf values. We recommend to delete this feature column.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: UserWarning: phasic_entropy contains more than 5% (actual: 62.03%) nan, inf, or -inf values. We recommend to delete this feature column.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Text(0.5, 1.0, 'Participant8')

# %%
import flirt.reader.empatica
import matplotlib.pyplot as plot

eda = flirt.reader.empatica.read_eda_file_into_df("/content/sample_data/P9_EDA.csv")
eda_features = flirt.get_eda_features(eda['eda'], 180, 1)

eda_features[['phasic_std']].plot()
plot.title("Participant9")
# Out:
# EDA features:   0%|          | 0/537 [00:00<?, ?it/s]
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: UserWarning: tonic_entropy contains more than 5% (actual: 38.73%) nan, inf, or -inf values. We recommend to delete this feature column.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: UserWarning: phasic_entropy contains more than 5% (actual: 76.35%) nan, inf, or -inf values. We recommend to delete this feature column.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Text(0.5, 1.0, 'Participant9')

# %%
import flirt.reader.empatica
import matplotlib.pyplot as plot

eda = flirt.reader.empatica.read_eda_file_into_df("/content/sample_data/P10_EDA.csv")
eda_features = flirt.get_eda_features(eda['eda'], 180, 1)

eda_features[['phasic_std']].plot()
plot.title("Participant10")
# Out:
# EDA features:   0%|          | 0/290 [00:00<?, ?it/s]
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: UserWarning: tonic_entropy contains more than 5% (actual: 63.1%) nan, inf, or -inf values. We recommend to delete this feature column.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: UserWarning: phasic_entropy contains more than 5% (actual: 43.1%) nan, inf, or -inf values. We recommend to delete this feature column.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Text(0.5, 1.0, 'Participant10')

# %%
import flirt.reader.empatica
import matplotlib.pyplot as plot

eda = flirt.reader.empatica.read_eda_file_into_df("/content/sample_data/P11_EDA.csv")
eda_features = flirt.get_eda_features(eda['eda'], 180, 1)

eda_features[['phasic_std']].plot()
plot.title("Participant11")
# Out:
# EDA features:   0%|          | 0/494 [00:00<?, ?it/s]
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: UserWarning: tonic_entropy contains more than 5% (actual: 38.06%) nan, inf, or -inf values. We recommend to delete this feature column.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: UserWarning: phasic_entropy contains more than 5% (actual: 77.73%) nan, inf, or -inf values. We recommend to delete this feature column.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Text(0.5, 1.0, 'Participant11')

# %%
import flirt.reader.empatica
import matplotlib.pyplot as plot

eda = flirt.reader.empatica.read_eda_file_into_df("/content/sample_data/P12_EDA.csv")
eda_features = flirt.get_eda_features(eda['eda'], 180, 1)

eda_features[['phasic_std']].plot()
plot.title("Participant12")
# Out:
# EDA features:   0%|          | 0/273 [00:00<?, ?it/s]
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: UserWarning: tonic_entropy contains more than 5% (actual: 66.3%) nan, inf, or -inf values. We recommend to delete this feature column.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: UserWarning: phasic_entropy contains more than 5% (actual: 43.59%) nan, inf, or -inf values. We recommend to delete this feature column.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Text(0.5, 1.0, 'Participant12')

# %%
import flirt.reader.empatica
import matplotlib.pyplot as plot

eda = flirt.reader.empatica.read_eda_file_into_df("/content/sample_data/P13_EDA.csv")
eda_features = flirt.get_eda_features(eda['eda'], 180, 1)

eda_features[['phasic_std']].plot()
plot.title("Participant13")
# Out:
# EDA features:   0%|          | 0/315 [00:00<?, ?it/s]
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: UserWarning: tonic_entropy contains more than 5% (actual: 57.46%) nan, inf, or -inf values. We recommend to delete this feature column.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: UserWarning: phasic_entropy contains more than 5% (actual: 84.44%) nan, inf, or -inf values. We recommend to delete this feature column.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Text(0.5, 1.0, 'Participant13')

# %%
import flirt.reader.empatica
import matplotlib.pyplot as plot

eda = flirt.reader.empatica.read_eda_file_into_df("/content/sample_data/P14_EDA.csv")
eda_features = flirt.get_eda_features(eda['eda'], 180, 1)

eda_features[['phasic_std']].plot()
plot.title("Participant14")
# Out:
# EDA features:   0%|          | 0/354 [00:00<?, ?it/s]
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: UserWarning: tonic_entropy contains more than 5% (actual: 24.58%) nan, inf, or -inf values. We recommend to delete this feature column.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: UserWarning: phasic_entropy contains more than 5% (actual: 70.9%) nan, inf, or -inf values. We recommend to delete this feature column.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Text(0.5, 1.0, 'Participant14')
